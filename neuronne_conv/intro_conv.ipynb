# %%
import cv2

# %%
img = cv2.imread("grumpy_cat.jpg")

type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (885, 640, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
import numpy as np
kernel = np.ones((10, 10)) / 100
kernel
# Out:
# array([[0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01],
#        [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01]])

# %%
result = cv2.filter2D(img, -1, kernel)
plt.imshow(result)

# %%
kernel = np.array([

    [-1, -1, -1], # k1, k2, k3
    [-1, 8, -1], # k4, k5, k6
    [-1, -1, -1] #k7, k8, k9
])

result = cv2.filter2D(img, -1, kernel)
plt.imshow(result)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
model = Sequential()

model.add(Conv2D(34, activation="relu", kernel_size=(3,3))) # ma convolution a un kernel de taille 3x3
model.add(Conv2D(64, activation="relu", kernel_size=(3,3)))
model.add(Flatten()) # -> redimensionne juste les données (np.reshape en gros)
model.add(Dense(200, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd")

model.fit(x_train, y_train)
